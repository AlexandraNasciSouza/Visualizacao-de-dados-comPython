# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

# %%
carros = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos, 
#em que seja possível diferenciar o país de origem (‘origin’). Sabendo disso, existe uma correlação entre a aceleração e o 
#consumo? De que tipo? A correlação é a mesma para os diferentes países de origem? Você pode escolher a técnica que julgar mais 
#adequada!
#R = Sim, baixa correlação positiva. Quanto mais acelera mais gasta. Não.


plt.figure(figsize=(8,5))
plt.title('Relação entre a aceleração e o consumo de combustível, diferenciando o país de origem')        
sns.scatterplot(x="mpg", y='acceleration', hue='origin', data=carros)
plt.show()

# %%
#Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos,
#em que seja possível visualizar o ano do modelo (model_year). Existe alguma relação entre as três variáveis?
#A meu ver não tem muita relação.

plt.figure(figsize=(8,5))
plt.title('Relação entre a aceleração e o consumo de combustível, diferenciando o país de origem')        
sns.scatterplot(x="mpg", y='acceleration', hue='model_year', data=carros)
plt.show()
