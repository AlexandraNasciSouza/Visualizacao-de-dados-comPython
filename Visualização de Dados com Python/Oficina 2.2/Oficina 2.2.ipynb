# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jogos = pd.read_csv('dadosoficina04.txt')
jogos
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Crie uma visualização que mostre a proporção de vendas global entre gêneros de jogos da empresa Nintendo;
jogos_nintendo = jogos[jogos['Publisher'] == 'Nintendo'].groupby('Genre').sum()
jogos_nintendo
# Out:
#                 Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        359543  156516.0     63.49     29.02     29.24         6.48
# Adventure     193705   70161.0     17.72      7.66      9.01         1.28
# Fighting       47056   36031.0     27.10      8.64     14.94         2.65
# Misc          523309  200625.0     61.98     51.62     55.25        11.78
# Platform      245890  222146.0    220.14     85.21    102.36        19.47
# Puzzle        327830  148134.0     55.74     26.42     37.09         5.53
# Racing         82066   73967.0     73.55     39.75     29.22         8.81
# Role-Playing  374106  210720.0    105.63     63.92    102.24        13.07
# Shooter        98683   48030.0     51.39      9.85      6.07         2.39
# Simulation    112905   56156.0     29.70     26.05     23.67         5.86
# Sports        186935  110069.0     98.77     66.18     35.87        17.18
# Strategy      162136   62111.0     11.66      4.42     10.46         0.83
# ...

# %%
jogos_nintendo = jogos[jogos['Publisher'] == 'Nintendo'].groupby('Genre').sum()
vendas = jogos_nintendo['Global_Sales']
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(15,5))
plt.bar(jogos_nintendo.index, vendas)
plt.show()

# %%
#Crie uma visualização que mostre a proporção de quantidade de jogos por plataforma a partir do ano de 2015.
jogos_ano = jogos[jogos['Year'] >= 2015].groupby('Platform').count()
jogos_ano
# Out:
#           Rank  Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 3DS        121   121   121    121        121       121       121       121
# DS           1     1     1      1          1         1         1         1
# PC          88    88    88     88         88        88        88        88
# PS3        106   106   106    106        106       106       106       106
# PS4        245   245   245    245        245       245       245       245
# PSP          3     3     3      3          3         3         3         3
# PSV        175   175   175    175        173       175       175       175
# Wii          4     4     4      4          4         4         4         4
# WiiU        38    38    38     38         38        38        38        38
# X360        48    48    48     48         48        48        48        48
# XOne       133   133   133    133        133       133       133       133
#
#           Other_Sales  Global_Sales
# Platform
# ...

# %%
jogos_ano = jogos[jogos['Year'] >= 2015].groupby('Platform').count()
ano = jogos_ano['Year']
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(15,5))
plt.bar(jogos_ano.index, ano)
plt.show()
