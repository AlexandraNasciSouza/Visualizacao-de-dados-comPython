# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('dadosoficina05.txt')
df.head(100)
# Out:
#               city  area  rooms  bathroom  parking spaces floor     animal  \
# 0        São Paulo    70      2         1               1     7      acept
# 1     Porto Alegre    80      1         1               1     6      acept
# 2     Porto Alegre    51      2         1               0     2      acept
# 3        São Paulo    25      1         1               0     1  not acept
# 4   Rio de Janeiro    72      2         1               0     7      acept
# ..             ...   ...    ...       ...             ...   ...        ...
# 95       São Paulo    76      3         1               1     4      acept
# 96       São Paulo   192      3         3               2    13      acept
# 97       São Paulo    68      2         1               1     5      acept
# 98       São Paulo   110      3         2               2     2      acept
# 99  Belo Horizonte    95      2         2               1     3      acept
#
#         furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
#Crie uma visualização que mostre a distribuição dos valores de aluguel, ‘rent amount (R$)’, dos imóveis. 
#Pode utilizar o gráfico que você julgar mais adequado. Qual faixa de valores de aluguel é mais comum?
# R= Entre uns 700(mais ou menos) a 5000.

plt.figure(figsize=(10, 5))
plt.title('Distribuição dos valores de aluguel')
sns.histplot(df['rent amount (R$)'])
plt.show()

# %%
#Crie uma visualização que mostre a distribuição dos valores de seguro contra incêndio, 'fire insurance (R$)', 
#dos imóveis. Existem valores incomuns? 
# R = Sim.

plt.figure(figsize=(10, 5))
plt.title('Distribuição dos valores de aluguel')
sns.histplot(df['fire insurance (R$)'])
plt.show()
